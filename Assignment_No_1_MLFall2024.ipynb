# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/diabetes.csv')

# %%
df.head()
# Out:
#    Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0.0            6      148             72             35        0  33.6
# 1    1.0            1       85             66             29        0  26.6
# 2    2.0            8      183             64              0        0  23.3
# 3    3.0            1       89             66             23       94  28.1
# 4    4.0            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 0                     0.627   50        1        1.0
# 1                     0.351   31        0       -1.0
# 2                     0.672   32        1        1.0
# 3                     0.167   21        0       -1.0
# 4                     2.288   33        1        1.0

# %%
df.tail()
# Out:
#      Index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763    NaN           10      101             76             48      180  32.9
# 764    NaN            2      122             70             27        0  36.8
# 765    NaN            5      121             72             23      112  26.2
# 766    NaN            1      126             60              0        0  30.1
# 767    NaN            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 763                     0.171   63        0        NaN
# 764                     0.340   27        0        NaN
# 765                     0.245   30        0        NaN
# 766                     0.349   47        1        NaN
# 767                     0.315   23        0        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  Outcome.1                 27 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 66.1 KB

# %%
df.mean()
# Out:
# Index                         4.500000
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# Outcome.1                     0.333333
# dtype: float64

# %%
df.min()
# Out:
# Index                        0.000
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# Outcome.1                   -1.000
# dtype: float64

# %%
df.describe()
# Out:
#           Index  Pregnancies     Glucose  BloodPressure  SkinThickness  \
# count  10.00000   768.000000  768.000000     768.000000     768.000000
# mean    4.50000     3.845052  120.894531      69.105469      20.536458
# std     3.02765     3.369578   31.972618      19.355807      15.952218
# min     0.00000     0.000000    0.000000       0.000000       0.000000
# 25%     2.25000     1.000000   99.000000      62.000000       0.000000
# 50%     4.50000     3.000000  117.000000      72.000000      23.000000
# 75%     6.75000     6.000000  140.250000      80.000000      32.000000
# max     9.00000    17.000000  199.000000     122.000000      99.000000
#
#           Insulin         BMI  DiabetesPedigreeFunction         Age  \
# count  768.000000  768.000000                768.000000  768.000000
# mean    79.799479   31.992578                  0.471876   33.240885
# std    115.244002    7.884160                  0.331329   11.760232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     10 non-null     float64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    int64
#  10  Outcome.1                 27 non-null     float64
# dtypes: float64(4), int64(7)
# memory usage: 66.1 KB

# %%
df.drop(columns='Pregnancies',axis=1)
# Out:
#      Index  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0.0      148             72             35        0  33.6
# 1      1.0       85             66             29        0  26.6
# 2      2.0      183             64              0        0  23.3
# 3      3.0       89             66             23       94  28.1
# 4      4.0      137             40             35      168  43.1
# ..     ...      ...            ...            ...      ...   ...
# 763    NaN      101             76             48      180  32.9
# 764    NaN      122             70             27        0  36.8
# 765    NaN      121             72             23      112  26.2
# 766    NaN      126             60              0        0  30.1
# 767    NaN       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Outcome.1
# 0                       0.627   50        1        1.0
# 1                       0.351   31        0       -1.0
# ...

# %%
df.iloc[2]
# Out:
# Index                         2.000
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# Outcome.1                     1.000
# Name: 2, dtype: float64

# %%
df.iloc[:,2]
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
df.corr()
# Out:
#                              Index  Pregnancies   Glucose  BloodPressure  \
# Index                     1.000000     0.241000  0.083791      -0.064371
# Pregnancies               0.241000     1.000000  0.129459       0.141282
# Glucose                   0.083791     0.129459  1.000000       0.152590
# BloodPressure            -0.064371     0.141282  0.152590       1.000000
# SkinThickness            -0.215358    -0.081672  0.057328       0.207371
# Insulin                   0.390339    -0.073535  0.331357       0.088933
# BMI                      -0.364901     0.017683  0.221071       0.281805
# DiabetesPedigreeFunction -0.264814    -0.033523  0.137337       0.041265
# Age                       0.288982     0.544341  0.263514       0.239528
# Outcome                   0.142134     0.221898  0.466581       0.065068
# Outcome.1                 0.142134     0.118031  0.471787       0.082255
#
#                           SkinThickness   Insulin       BMI  \
# ...

# %%
df.max()
# Out:
# Index                         9.00
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# Outcome.1                     1.00
# dtype: float64

# %%
df.min()
# Out:
# Index                        0.000
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# Outcome.1                   -1.000
# dtype: float64

# %%
df.std()
# Out:
# Index                         3.027650
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# Outcome.1                     0.960769
# dtype: float64
